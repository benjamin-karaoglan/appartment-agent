# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/carrefour/appartment-agent/data/dvf/ValeursFoncieres-2021.txt", delimiter="|")
# Out:
# /var/folders/84/0bjchfj14_5g93y_pyglq8t80000gp/T/ipykernel_72386/1469995501.py:1: DtypeWarning: Columns (18,23,24,26,28,29,30,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/carrefour/appartment-agent/data/dvf/ValeursFoncieres-2021.txt", delimiter="|")

# %%
df_ndc = df[df.Voie == "NOTRE-DAME DES CHAMPS"]

# %%
pd.set_option('display.max_columns', None)

# %%
df_ndc[df_ndc["No voie"] == 56]
# Out:
#          Identifiant de document  Reference document  1 Articles CGI  \
# 4654717                      NaN                 NaN             NaN
# 4654718                      NaN                 NaN             NaN
#
#          2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 4654717             NaN             NaN             NaN             NaN
# 4654718             NaN             NaN             NaN             NaN
#
#          No disposition Date mutation Nature mutation Valeur fonciere  \
# 4654717               1    07/12/2021           Vente      1340000,00
# 4654718               1    07/12/2021           Vente      1340000,00
#
#          No voie B/T/Q Type de voie Code voie                   Voie  \
# 4654717     56.0   NaN          RUE      6838  NOTRE-DAME DES CHAMPS
# 4654718     56.0   NaN          RUE      6838  NOTRE-DAME DES CHAMPS
#
#          Code postal   Commune Code departement  Code commune  \
# ...
